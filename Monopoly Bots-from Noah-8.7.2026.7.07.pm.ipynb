# %%
import numpy as np
class game():
    bots=[]
    num_players=0
    def __init__(self,bots=[]):
        self.bots=bots
    def add_bot(self,bot):
        bot.parent_game=self
        self.bots+=[bot]
        self.num_players+=1
class bot():
    name=''
    parent_game=game()
    Money=[]
    properties=[]
    chance=blank_card()
    community=blank_card()
    Monetary_preferences={}
    in_jail=False
    def __init__(self, name='', Monetary_preferences):
        self.name=name
        self.Monetary_preferences=Monetary_preferences
    def display_assets(self):
        print('Assets for bot '+self.name)
        print('Money = $'+str(self.Money))
        print('Properties:')
        for p in self.properties:
            p.display_prop()
        print('Chance Card:')
        self.chance.display_card()
        print('Community Chest Card:')
        self.community.display_card()
        if(self.in_jail):
            print(self.name+' is in jail')
    def display_secret(self):
        print(self.Monetary_preferences)
    def check_use_card(self,situation='End of turn'):#Prints 'Used' if used (plus target if applicable). Prints 'Does not use card' if not used.
        #Situations are end of turn and beginning of turn (i.e. before dice roll). Maybe it should just ignore the beginning of the turn?
    def check_build(self,situation='End of turn'):

    def check_jail_bailout(self):
        
    def evaluate_trade(trade):
        
default_preferences_1={}
class prop():
    num_houses=0
    color_set='N/A'
    cards_in_set=3
    cost=0
    mortgaged=False
    rents=[0,0,0,0,0,0]
    name=''
    def __init__(self,name,color_set,cards_in_set,rents):
        self.name=name
        self.color_set=color_set
        self.cards_in_set=cards_in_set
        self.rents=rents
    def display_prop(self):
        print('Property:'+self.name)
        if(self.mortgaged):
            print('Property IS mortgaged')
            print('Price to unmortgage: $'+round(str(cost*0.55)))
        else:
            print('Property is NOT mortgaged')
            print('Money from mortgaging: $'+round(str(cost*0.5)))
All_properties=[]
class card():
    card_name='Placeholder'
    action_statement='Does nothing'
    def __init__(self,name,statement):

    def display_card(self)
def blank_card():
    return card()
class trade_offer():
    offerred_properties=[]
    #offerred_cards=[]
    offerred_money=0 #Negative if you are offerring the bot money
    asked_for_properties=[]
    #asked_for_cards=[]
    def __init__(self,off_props,off_money,asked_props):
